# %%
import os
import json
import numpy as np
import pandas as pd
import seaborn as sns
import scipy as scp

def mean(x):
    return scp.stats.trim_mean(x, 0.2)

def std(x):
    x = np.array(x)
    x.sort()
    low = int(0.2 * len(x))
    high = int(0.8 * len(x))
    
    return x[low:high].std(ddof=0)

param_dir = os.path.join("..", "out", "param")
results = []
for fname in os.listdir(param_dir):
    with open(os.path.join(param_dir, fname)) as f:
        results.append(json.load(f))
df = pd.DataFrame(data=results)
#print(df)

exp1 = df.groupby(["dataset", "num_train_data", "mix_strategy"])["test_acc"].agg([mean, std, "count"])
exp1
# Out:
# /home/sh0416/anaconda3/envs/python3.8/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/sh0416/anaconda3/envs/python3.8/lib/python3.8/site-packages/numpy/core/_methods.py:194: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(
# /home/sh0416/anaconda3/envs/python3.8/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#                                                             mean       std  \
# dataset                num_train_data mix_strategy
# ag_news                40             mixuptransformer  0.860000  0.000474
#                                       none              0.852401  0.002731
#                                       nonlinearmix      0.851678  0.001747
#                                       oommix            0.848918  0.001346
#                                       tmix              0.852105  0.001626
#                        500            mixuptransformer  0.885789  0.000186
#                                       none              0.882237  0.000186
#                                       nonlinearmix      0.882412  0.000541
#                                       oommix            0.884079  0.000468
#                                       tmix              0.884474  0.000186
#                        2500           mixuptransformer  0.896228  0.000895
#                                       nonlinearmix      0.887368  0.003648
#                        10000          mixuptransformer  0.913684  0.002058
#                                       nonlinearmix      0.888553  0.001220
#                        30000          oommix            0.917456  0.003355
#                                       tmix              0.920658  0.000000
# amazon_review_polarity 40             mixuptransformer  0.808242  0.019334
#                                       none              0.789839  0.005657
#                                       nonlinearmix      0.747490  0.015059
#                                       tmix              0.816059  0.006346
#                        500            mixuptransformer  0.893141  0.001351
#                                       none              0.891710  0.003452
#                                       nonlinearmix      0.890159  0.002055
#                                       oommix            0.896570  0.001197
#                                       tmix              0.895788  0.000195
#                        2500           mixuptransformer  0.907042  0.000519
#                                       nonlinearmix      0.910388  0.001132
#                        10000          mixuptransformer  0.921220  0.002842
#                                       nonlinearmix      0.911502  0.004202
# dbpedia                140            mixuptransformer  0.967807  0.001078
#                                       none              0.963696  0.002731
#                                       nonlinearmix      0.944925  0.003786
#                                       tmix              0.963290  0.000824
#                        500            mixuptransformer  0.980567  0.000521
#                                       none              0.978657  0.000686
#                                       nonlinearmix      0.975057  0.002496
#                                       oommix            0.982671  0.000435
#                                       tmix              0.981457  0.000959
#                        2800           mixuptransformer  0.987562  0.000125
#                                       nonlinearmix      0.959043  0.039652
#                        35000          mixuptransformer  0.989257  0.000369
#                                       nonlinearmix      0.977243  0.016405
# yahoo_answer           40             mixuptransformer  0.520483       NaN
#                        100            mixuptransformer  0.601800  0.006286
#                                       none              0.590396  0.001415
#                                       nonlinearmix      0.578163  0.050824
#                                       tmix              0.605644  0.003055
#                        500            mixuptransformer  0.676283  0.000636
#                                       none              0.672400  0.000722
#                                       nonlinearmix      0.663561  0.014394
#                                       oommix            0.679522  0.001616
#                                       tmix              0.675706  0.001089
#                        2000           mixuptransformer  0.702872  0.001402
#                                       nonlinearmix      0.676817  0.020165
#                        25000          mixuptransformer  0.735289  0.000479
#                                       nonlinearmix      0.693056  0.003744
#
#                                                         count
# dataset                num_train_data mix_strategy
# ag_news                40             mixuptransformer     17
#                                       none                  4
#                                       nonlinearmix          4
#                                       oommix               13
#                                       tmix                  5
#                        500            mixuptransformer      5
#                                       none                  5
#                                       nonlinearmix          5
#                                       oommix                5
#                                       tmix                  5
#                        2500           mixuptransformer      5
#                                       nonlinearmix          5
#                        10000          mixuptransformer      5
#                                       nonlinearmix          5
#                        30000          oommix                3
#                                       tmix                  2
# amazon_review_polarity 40             mixuptransformer      4
#                                       none                  4
#                                       nonlinearmix          4
#                                       tmix                  5
#                        500            mixuptransformer      5
#                                       none                  5
#                                       nonlinearmix          5
#                                       oommix               86
#                                       tmix                  5
#                        2500           mixuptransformer      5
#                                       nonlinearmix          5
#                        10000          mixuptransformer      5
#                                       nonlinearmix          5
# dbpedia                140            mixuptransformer      4
#                                       none                  4
#                                       nonlinearmix          4
#                                       tmix                  5
#                        500            mixuptransformer      5
#                                       none                  5
#                                       nonlinearmix          5
#                                       oommix                5
#                                       tmix                  5
#                        2800           mixuptransformer      5
#                                       nonlinearmix          5
#                        35000          mixuptransformer      4
#                                       nonlinearmix          5
# yahoo_answer           40             mixuptransformer      1
#                        100            mixuptransformer      4
#                                       none                  4
#                                       nonlinearmix          4
#                                       tmix                  5
#                        500            mixuptransformer      5
#                                       none                  5
#                                       nonlinearmix          5
#                                       oommix                5
#                                       tmix                  5
#                        2000           mixuptransformer      5
#                                       nonlinearmix          5
#                        25000          mixuptransformer      5
#                                       nonlinearmix          5

# %%
import numpy as np
import matplotlib.pyplot as plt

sns.set_theme(context="paper", style="ticks", font_scale=1.7)
matrix = np.zeros((6, 7))

fig, ax = plt.subplots(figsize=(8, 6))
for idx, row in df[(df["dataset"]=="amazon_review_polarity")&(df["mix_strategy"]=="oommix")].groupby(["m_layer", "d_layer"])["test_acc"].mean().iteritems():
    matrix[(idx[0]//2, idx[1]//2)] = 100*row
mask = matrix == 0

ax = sns.heatmap(matrix, mask=mask, linewidths=1.5, cmap="YlGnBu",
                 xticklabels=[0, 2, 4, 6, 8, 10, 12],
                 yticklabels=[0, 2, 4, 6, 8, 10],
                 annot=True, fmt=".2f")
ax.set_ylabel("Generator layer", fontsize=20)
ax.set_xlabel("Discriminator layer", fontsize=20)
plt.tight_layout()
plt.savefig("exp4.png", dpi=200)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ea18d83d0acb> in <module>
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 sns.set_theme(context="paper", style="ticks", font_scale=1.7)
#       5 matrix = np.zeros((6, 7))
#       6
#
# NameError: name 'sns' is not defined

# %%
df[(df["mix_strategy"]=="oommix")&(df["dataset"]=="yahoo_answer")&(df["num_train_data"]==500)]
# Out:
#      seed                                         data_dir       dataset  \
# 25      2  /data/sh0416/dataset/pdistmix/yahoo_answers_csv  yahoo_answer
# 130     1  /data/sh0416/dataset/pdistmix/yahoo_answers_csv  yahoo_answer
# 147     0  /data/sh0416/dataset/pdistmix/yahoo_answers_csv  yahoo_answer
# 175     4  /data/sh0416/dataset/pdistmix/yahoo_answers_csv  yahoo_answer
# 316     3  /data/sh0416/dataset/pdistmix/yahoo_answers_csv  yahoo_answer
#
#      num_train_data data_augment  max_length restore  epoch  batch_size  \
# 25              500         none         256    None   5000          12
# 130             500         none         256    None   5000          12
# 147             500         none         256    None   5000          12
# 175             500         none         256    None   5000          12
# 316             500         none         256    None   5000          12
#
#           lr  ...  mix_strategy m_layer  d_layer  alpha  coeff_intr  \
# 25   0.00002  ...        oommix       3       12    0.2         0.5
# 130  0.00002  ...        oommix       3       12    0.2         0.5
# 147  0.00002  ...        oommix       3       12    0.2         0.5
# 175  0.00002  ...        oommix       3       12    0.2         0.5
# 316  0.00002  ...        oommix       3       12    0.2         0.5
#
#      eval_every  patience  gpu        exp_id  test_acc
# 25          200        10    3  bd9700bb-488  0.674583
# 130         200        10    2  2ae2ae09-bf9  0.680333
# 147         200        10    1  bb1a5466-1b7  0.680967
# 175         200        10    1  27c2da6b-d5c  0.677267
# 316         200        10    0  59e6c11f-193  0.683150
#
# [5 rows x 21 columns]

# %%
import torch
ckpt = torch.load("../out/ckpt/model_bd9700bb-488.pth", map_location=torch.device("cpu"))

# %%
sum(v.numel() for k, v in ckpt.items())
# Out:
# 114014862

# %%
df[(df["dataset"]=="yahoo_answer")&(df["num_train_data"] == 2000)]
# Out:
#     seed                                         data_dir       dataset  \
# 2      2  /data/sh0416/dataset/pdistmix/yahoo_answers_csv  yahoo_answer
# 3      4  /data/sh0416/dataset/pdistmix/yahoo_answers_csv  yahoo_answer
# 18     0  /data/sh0416/dataset/pdistmix/yahoo_answers_csv  yahoo_answer
# 21     1  /data/sh0416/dataset/pdistmix/yahoo_answers_csv  yahoo_answer
# 25     3  /data/sh0416/dataset/pdistmix/yahoo_answers_csv  yahoo_answer
#
#     num_train_data data_augment  max_length restore  epoch  batch_size  \
# 2             2000         none         256    None   1000          12
# 3             2000         none         256    None   1000          12
# 18            2000         none         256    None   1000          12
# 21            2000         none         256    None   1000          12
# 25            2000         none         256    None   1000          12
#
#          lr  ...  mix_strategy m_layer  d_layer  alpha  coeff_intr  \
# 2   0.00002  ...  nonlinearmix       3       12    0.2         0.5
# 3   0.00002  ...  nonlinearmix       3       12    0.2         0.5
# 18  0.00002  ...  nonlinearmix       3       12    0.2         0.5
# 21  0.00002  ...  nonlinearmix       3       12    0.2         0.5
# 25  0.00002  ...  nonlinearmix       3       12    0.2         0.5
#
#     eval_every  patience  gpu        exp_id  test_acc
# 2          200         3    0  ac672485-3e8  0.648300
# 3          200         3    2  213aa171-29d  0.692850
# 18         200         3    2  b24e3ffd-ac3  0.690817
# 21         200         3    3  66bd86f3-5b0  0.691333
# 25         200         3    1  40dded59-1dc  0.520833
#
# [5 rows x 21 columns]

# %%
df[(df["dataset"]=="dbpedia")&(df["num_train_data"] == 35000)]
# Out:
#     seed                                   data_dir  dataset  num_train_data  \
# 4      1  /data/sh0416/dataset/pdistmix/dbpedia_csv  dbpedia           35000
# 12     4  /data/sh0416/dataset/pdistmix/dbpedia_csv  dbpedia           35000
# 26     3  /data/sh0416/dataset/pdistmix/dbpedia_csv  dbpedia           35000
# 29     0  /data/sh0416/dataset/pdistmix/dbpedia_csv  dbpedia           35000
# 37     2  /data/sh0416/dataset/pdistmix/dbpedia_csv  dbpedia           35000
#
#    data_augment  max_length restore  epoch  batch_size       lr  ...  \
# 4          none         256    None   1000          12  0.00002  ...
# 12         none         256    None   1000          12  0.00002  ...
# 26         none         256    None   1000          12  0.00002  ...
# 29         none         256    None   1000          12  0.00002  ...
# 37         none         256    None   1000          12  0.00002  ...
#
#     mix_strategy m_layer  d_layer  alpha  coeff_intr  eval_every  patience  \
# 4   nonlinearmix       3       12    0.2         0.5         200         3
# 12  nonlinearmix       3       12    0.2         0.5         200         3
# 26  nonlinearmix       3       12    0.2         0.5         200         3
# 29  nonlinearmix       3       12    0.2         0.5         200         3
# 37  nonlinearmix       3       12    0.2         0.5         200         3
#
#     gpu        exp_id  test_acc
# 4     0  09791bea-a74  0.988757
# 12    3  d6679b70-7f2  0.989057
# 26    2  0124ad6c-782  0.913057
# 29    3  5713f9ba-11c  0.988929
# 37    1  38e9dc8b-239  0.954043
#
# [5 rows x 21 columns]
